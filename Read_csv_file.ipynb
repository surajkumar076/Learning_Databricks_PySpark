# %%
dbutils.fs.ls("/FileStore/tables/DataSet")
# Out:
# Out[1]: [FileInfo(path='dbfs:/FileStore/tables/DataSet/colors.json', name='colors.json', size=5056, modificationTime=1658513579000),
#  FileInfo(path='dbfs:/FileStore/tables/DataSet/eg_sample.parquet', name='eg_sample.parquet', size=2960, modificationTime=1658513579000),
#  FileInfo(path='dbfs:/FileStore/tables/DataSet/sample.csv', name='sample.csv', size=2214, modificationTime=1658513580000),
#  FileInfo(path='dbfs:/FileStore/tables/DataSet/sample2.csv', name='sample2.csv', size=47, modificationTime=1658513580000),
#  FileInfo(path='dbfs:/FileStore/tables/DataSet/sheet1.csv', name='sheet1.csv', size=219, modificationTime=1658513581000)]

# %%
df = spark.read.format("csv").option('inferSchema', True).option("header", True).option("sep", ",").load("/FileStore/tables/DataSet/sample.csv")
display(df)
print(df.count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Read Mutiple CSV Files
df = spark.read.format("csv").option('inferSchema', True).option("header", True).option("sep", ",").load(["/FileStore/tables/DataSet/sample.csv", "/FileStore/tables/DataSet/sheet1.csv"])

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Read all CSV files under a Folder
df = spark.read.format("csv").option('inferSchema', True).option("header", True).option("sep", ",").load("/FileStore/tables/DataSet/")
display(df)
print(df.count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# <��</td></tr><tr><td>2014-08-27 11:29:31</td></tr><tr><td>2014-08-27 11:29:37</td></tr><tr><td>2014-08-27 11:29:44</td></tr><tr><td>2014-08-27 11:29:46</td></tr><tr><td>2014-08-27 11:30:22</td></tr><tr><td>2014-08-27 11:31:22</td></tr><tr><td>2014-08-27 11:31:50</td></tr><tr><td>2014-08-27 11:32:05</td></tr><tr><td>2014-08-27 11:32:39</td></tr><tr><td>1000</td></tr><tr><td>2000</td></tr><tr><td>3000</td></tr><tr><td>4000</td></tr><tr><td>5000</td></tr><tr><td>6000</td></tr><tr><td>Adam</td></tr><tr><td>Alex</td></tr><tr><td>Mia</td></tr><tr><td>Ola</td></tr></tbody></table></div>
# 173

# %%
df.printSchema()
# Out:
# root
#  |-- {: string (nullable = true)
